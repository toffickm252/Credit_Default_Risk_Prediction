# %%
import os
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, roc_curve, auc, precision_recall_curve,
    f1_score, accuracy_score, precision_score, recall_score,
    roc_auc_score, classification_report
)

# %%
# Create output directory for saved visualizations
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
viz_dir = os.path.join(base_dir, "reports", "visualizations")
os.makedirs(viz_dir, exist_ok=True)

print("✅ Imports loaded and visualization directory ready")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Create output directory for saved visualizations
# ----> 2 base_dir = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#       3 viz_dir = os.path.join(base_dir, "reports", "visualizations")
#       4 os.makedirs(viz_dir, exist_ok=True)
#
# NameError: name '__file__' is not defined
